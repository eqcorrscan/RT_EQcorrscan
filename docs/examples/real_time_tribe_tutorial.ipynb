# %% [markdown]
# # Real Time Tribe
#
# The `RealTimeTribe` class provides (near) real-time matched-filter methods.  It subclasses EQcorrscan's `Tribe` class and therefore
# provides all the same methods, as well as real-time methods. We simply make a `RealTimeTribe` from a `Tribe` and some streaming client.
# RT-EQcorrscan provides a `_Streaming` abstract base class outlining the basic attributes and methods a streaming client needs to have for
# real-time matched-filtering.  The `RealTimeClient` is a mix of obspy's `EasySeedLinkClient` and the `_Streaming` abc, providing
# access to seedlink services for real-time matched-filtering.
#
# In this example we will see what seismicity is going on associated with the Rigdecrest sequence in California.

# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from eqcorrscan import Tribe
from eqcorrscan.utils.catalog_utils import filter_picks
from rt_eqcorrscan import RealTimeTribe
from rt_eqcorrscan.streaming import RealTimeClient

client = Client("NCEDC")  # IRIS doesn't provide picks
rt_client = RealTimeClient(
    server_url="rtserve.iris.washington.edu",
    buffer_capacity=600.) # NCEDC doesn't provide a public seedlink

template_catalog = client.get_events(
    latitude=35.7, longitude=-117.4, maxradius=0.2, 
    starttime=UTCDateTime(2019, 7, 1), endtime=UTCDateTime(2019, 7, 15), 
    minmagnitude=4.5, includearrivals=True)
_ = template_catalog.plot(projection="local")

# %% [markdown]
# We first have to generate a `Tribe` from this catalog. This will take a little while, and is one of the key motivations for using a `TemplateBank` of
# previously recorded earthquakes.
#
# For speed we will filter the catalog

# %%
filtered_catalog = filter_picks(
    template_catalog, top_n_picks=5, 
    networks=["PB", "LB", "US"])
tribe = Tribe().construct(
    method="from_client", catalog=filtered_catalog, client_id=Client("IRIS"),
    lowcut=2., highcut=15., samp_rate=50., filt_order=4, prepick=0.5, length=4.,
    swin="all", process_len=300.)
# Out:
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B901.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for TPH.HHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B076.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B079.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!
# Pick for B900.EHZ has no phase hint given, you should not use this template for cross-correlation re-picking!

# %% [markdown]
# We also need an inventory of stations that will be used.

# %%
seed_ids = {tuple(pick.waveform_id.get_seed_string().split('.'))
            for event in filtered_catalog for pick in event.picks}
bulk = [
    (sid[0], sid[1], sid[2], sid[3], UTCDateTime(2019, 7, 1), 
     UTCDateTime(2019, 7, 10)) for sid in seed_ids]
inventory = client.get_stations_bulk(bulk, level="channel")

# %% [markdown]
# Finally we can make the real-time tribe (note that plotting isn't supported in the notebook, but if you run this outside of the notebook and turn `plot=True` then you will get a bokeh live updating plot:

# %%
rt_tribe = RealTimeTribe(
        tribe=tribe, inventory=inventory, rt_client=rt_client,
        detect_interval=20, plot=False, plot_options=dict(plot_length=600.))

# %% [markdown]
# And we can run the (near) real-time detection!

# %%
import logging

logging.basicConfig(
    level="INFO", format="%(asctime)s\t%(name)s\t%(levelname)s\t%(message)s"
)

rt_tribe.run(
    threshold=0.25, threshold_type="av_chan_corr", trig_int=10., 
    max_run_length=1200)  # Max_run_length will stop the process - leave unset to run forever.
# Out:
# 2019-07-18 17:55:35,560	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	sending: requesting INFO level CAPABILITIES
# 2019-07-18 17:55:35,743	rt_eqcorrscan.streaming.streaming	INFO	Started streaming
# 2019-07-18 17:55:35,743	rt_eqcorrscan.rt_match_filter	INFO	Started real-time streaming
# 2019-07-18 17:55:35,744	rt_eqcorrscan.rt_match_filter	INFO	Detection will use the following data: {'LB.TPH.01.HHZ', 'PB.B900..EHZ', 'PB.B901..EHZ', 'PB.B079..EHZ', 'PB.B076..EHZ'}
# 2019-07-18 17:55:35,745	rt_eqcorrscan.rt_match_filter	INFO	Sleeping for 605.00s while accumulating data
# 2019-07-18 17:55:36,102	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	requesting next available data
# 2019-07-18 17:55:36,641	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	requesting next available data
# 2019-07-18 17:55:37,182	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	requesting next available data
# 2019-07-18 17:55:37,722	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	requesting next available data
# 2019-07-18 17:55:38,261	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	requesting next available data
# 2019-07-18 17:55:38,442	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	5 station(s) accepted
# 2019-07-18 18:05:40,848	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:05:41,003	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:00:23.198300Z and 2019-07-18T06:04:42.478300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:05:41,004	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:55:23.198300Z and 2019-07-18T06:00:23.178300Z
# 2019-07-18 18:05:41,027	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:05:41,100	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0701s
# 2019-07-18 18:05:41,107	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0062s
# 2019-07-18 18:05:41,131	eqcorrscan.core.match_filter.matched_filter	INFO	Made 49 detections from 11 templates
# 2019-07-18 18:05:41,154	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:05:41,158	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 20 detections
# 2019-07-18 18:05:41,158	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.31s
# 2019-07-18 18:05:41,158	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.69s until next run
# 2019-07-18 18:06:00,868	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:06:01,167	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:05:18.738400Z and 2019-07-18T06:05:19.748300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:06:01,168	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:55:28.718300Z and 2019-07-18T06:00:28.698300Z
# 2019-07-18 18:06:01,194	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:06:01,264	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0674s
# 2019-07-18 18:06:01,269	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0039s
# 2019-07-18 18:06:01,292	eqcorrscan.core.match_filter.matched_filter	INFO	Made 48 detections from 11 templates
# 2019-07-18 18:06:01,293	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:00:18.738300Z and 2019-07-18T06:05:18.718300Z
# 2019-07-18 18:06:01,316	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:06:01,384	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0655s
# 2019-07-18 18:06:01,390	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0048s
# 2019-07-18 18:06:01,417	eqcorrscan.core.match_filter.matched_filter	INFO	Made 60 detections from 11 templates
# 2019-07-18 18:06:01,555	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:06:01,560	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 45 detections
# 2019-07-18 18:06:01,561	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.70s
# 2019-07-18 18:06:01,561	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.30s until next run
# 2019-07-18 18:06:20,884	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:06:21,029	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:01:01.228300Z and 2019-07-18T06:05:24.118300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:06:21,029	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:56:01.228300Z and 2019-07-18T06:01:01.208300Z
# 2019-07-18 18:06:21,054	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:06:21,127	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0699s
# 2019-07-18 18:06:21,131	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0033s
# 2019-07-18 18:06:21,159	eqcorrscan.core.match_filter.matched_filter	INFO	Made 50 detections from 11 templates
# 2019-07-18 18:06:21,221	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:06:21,228	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 59 detections
# 2019-07-18 18:06:21,229	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.35s
# 2019-07-18 18:06:21,229	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.65s until next run
# 2019-07-18 18:06:40,905	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:06:41,053	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:01:08.888300Z and 2019-07-18T06:05:24.118300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:06:41,054	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:56:08.888300Z and 2019-07-18T06:01:08.868300Z
# 2019-07-18 18:06:41,077	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:06:41,138	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0582s
# 2019-07-18 18:06:41,143	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0041s
# 2019-07-18 18:06:41,168	eqcorrscan.core.match_filter.matched_filter	INFO	Made 51 detections from 11 templates
# 2019-07-18 18:06:41,210	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:06:41,216	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 63 detections
# 2019-07-18 18:06:41,216	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.32s
# 2019-07-18 18:06:41,217	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.68s until next run
# 2019-07-18 18:07:00,924	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:07:01,075	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:01:28.538300Z and 2019-07-18T06:06:01.228300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:07:01,075	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:56:28.538300Z and 2019-07-18T06:01:28.518300Z
# 2019-07-18 18:07:01,099	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:07:01,162	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0592s
# 2019-07-18 18:07:01,165	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0029s
# 2019-07-18 18:07:01,190	eqcorrscan.core.match_filter.matched_filter	INFO	Made 50 detections from 11 templates
# 2019-07-18 18:07:01,238	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:07:01,243	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 64 detections
# 2019-07-18 18:07:01,244	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.32s
# 2019-07-18 18:07:01,244	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.68s until next run
# 2019-07-18 18:07:20,931	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:07:21,087	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:01:47.448300Z and 2019-07-18T06:06:14.138300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:07:21,088	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:56:47.448300Z and 2019-07-18T06:01:47.428300Z
# 2019-07-18 18:07:21,116	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:07:21,178	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0597s
# 2019-07-18 18:07:21,183	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0036s
# 2019-07-18 18:07:21,209	eqcorrscan.core.match_filter.matched_filter	INFO	Made 49 detections from 11 templates
# 2019-07-18 18:07:21,252	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:07:21,259	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 65 detections
# 2019-07-18 18:07:21,260	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.33s
# 2019-07-18 18:07:21,260	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.67s until next run
# 2019-07-18 18:07:40,951	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:07:41,100	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:02:18.268300Z and 2019-07-18T06:06:44.658300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:07:41,100	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:57:18.268300Z and 2019-07-18T06:02:18.248300Z
# 2019-07-18 18:07:41,124	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:07:41,196	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0688s
# 2019-07-18 18:07:41,199	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0026s
# 2019-07-18 18:07:41,221	eqcorrscan.core.match_filter.matched_filter	INFO	Made 50 detections from 11 templates
# 2019-07-18 18:07:41,265	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:07:41,271	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 68 detections
# 2019-07-18 18:07:41,271	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.32s
# 2019-07-18 18:07:41,271	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.68s until next run
# 2019-07-18 18:08:00,968	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:08:01,161	eqcorrscan.utils.pre_processing	INFO	Data for LB.TPH.02.HHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,162	eqcorrscan.utils.pre_processing	INFO	Data for PB.B901..EHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,162	eqcorrscan.utils.pre_processing	INFO	Data for PB.B079..EHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,163	eqcorrscan.utils.pre_processing	INFO	Data for PB.B900..EHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,163	eqcorrscan.utils.pre_processing	INFO	Data for LB.TPH.01.HHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,163	eqcorrscan.utils.pre_processing	INFO	Data for PB.B076..EHZ are not long-enough, will zero pad
# 2019-07-18 18:08:01,265	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:57:18.268300Z and 2019-07-18T06:02:18.248300Z
# 2019-07-18 18:08:01,292	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:08:01,362	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0671s
# 2019-07-18 18:08:01,365	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0029s
# 2019-07-18 18:08:01,390	eqcorrscan.core.match_filter.matched_filter	INFO	Made 50 detections from 11 templates
# 2019-07-18 18:08:01,391	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:02:08.288300Z and 2019-07-18T06:07:08.268300Z
# 2019-07-18 18:08:01,411	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:08:01,478	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on LB.TPH.01.HHZ_0, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,479	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on LB.TPH.01.HHZ_1, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,479	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on PB.B076..EHZ_2, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,479	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on PB.B079..EHZ_3, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,480	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on PB.B900..EHZ_4, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,480	eqcorrscan.utils.correlate	WARNING	59 correlations not computed on PB.B901..EHZ_5, are there gaps in the data? If not, consider increasing gain
# 2019-07-18 18:08:01,481	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0675s
# 2019-07-18 18:08:01,486	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0044s
# 2019-07-18 18:08:01,519	eqcorrscan.core.match_filter.matched_filter	INFO	Made 63 detections from 11 templates
# 2019-07-18 18:08:01,663	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:08:01,672	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 83 detections
# 2019-07-18 18:08:01,673	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.71s
# 2019-07-18 18:08:01,674	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.29s until next run
# 2019-07-18 18:08:20,987	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:08:21,135	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:02:59.208300Z and 2019-07-18T06:07:35.718300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:08:21,136	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:57:59.208300Z and 2019-07-18T06:02:59.188300Z
# 2019-07-18 18:08:21,160	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:08:21,227	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0639s
# 2019-07-18 18:08:21,231	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0036s
# 2019-07-18 18:08:21,253	eqcorrscan.core.match_filter.matched_filter	INFO	Made 50 detections from 11 templates
# 2019-07-18 18:08:21,296	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:08:21,303	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 84 detections
# 2019-07-18 18:08:21,303	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.32s
# 2019-07-18 18:08:21,304	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.68s until next run
# 2019-07-18 18:08:41,009	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:08:41,161	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:03:21.308300Z and 2019-07-18T06:07:56.248300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:08:41,162	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:58:21.308300Z and 2019-07-18T06:03:21.288300Z
# 2019-07-18 18:08:41,185	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:08:41,249	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0613s
# 2019-07-18 18:08:41,254	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0040s
# 2019-07-18 18:08:41,282	eqcorrscan.core.match_filter.matched_filter	INFO	Made 51 detections from 11 templates
# 2019-07-18 18:08:41,323	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:08:41,332	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 84 detections
# 2019-07-18 18:08:41,332	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.33s
# 2019-07-18 18:08:41,333	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.67s until next run
# 2019-07-18 18:09:01,029	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:09:01,180	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:03:27.858300Z and 2019-07-18T06:07:58.608300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:09:01,181	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:58:27.858300Z and 2019-07-18T06:03:27.838300Z
# 2019-07-18 18:09:01,210	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:09:01,290	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0773s
# 2019-07-18 18:09:01,295	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0041s
# 2019-07-18 18:09:01,319	eqcorrscan.core.match_filter.matched_filter	INFO	Made 52 detections from 11 templates
# 2019-07-18 18:09:01,364	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:09:01,372	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 86 detections
# 2019-07-18 18:09:01,373	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.35s
# 2019-07-18 18:09:01,373	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.65s until next run
# 2019-07-18 18:09:21,048	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:09:21,198	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:03:53.018300Z and 2019-07-18T06:08:14.308300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:09:21,199	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T05:58:53.018300Z and 2019-07-18T06:03:52.998300Z
# 2019-07-18 18:09:21,224	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:09:21,300	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0736s
# 2019-07-18 18:09:21,305	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0042s
# 2019-07-18 18:09:21,334	eqcorrscan.core.match_filter.matched_filter	INFO	Made 51 detections from 11 templates
# 2019-07-18 18:09:21,377	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:09:21,385	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 87 detections
# 2019-07-18 18:09:21,385	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.34s
# 2019-07-18 18:09:21,386	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.66s until next run
# 2019-07-18 18:09:41,069	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# ...
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:14:01,463	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:08:20.608300Z and 2019-07-18T06:12:54.588300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:14:01,464	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:03:20.608300Z and 2019-07-18T06:08:20.588300Z
# 2019-07-18 18:14:01,490	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:14:01,563	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0696s
# 2019-07-18 18:14:01,567	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0030s
# 2019-07-18 18:14:01,599	eqcorrscan.core.match_filter.matched_filter	INFO	Made 70 detections from 11 templates
# 2019-07-18 18:14:01,658	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:14:01,672	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 155 detections
# 2019-07-18 18:14:01,673	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.38s
# 2019-07-18 18:14:01,673	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.62s until next run
# 2019-07-18 18:14:21,321	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:14:21,477	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:08:49.048300Z and 2019-07-18T06:13:13.548300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:14:21,478	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:03:49.048300Z and 2019-07-18T06:08:49.028300Z
# 2019-07-18 18:14:21,500	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:14:21,574	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0710s
# 2019-07-18 18:14:21,586	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0113s
# 2019-07-18 18:14:21,639	eqcorrscan.core.match_filter.matched_filter	INFO	Made 76 detections from 11 templates
# 2019-07-18 18:14:21,706	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:14:21,720	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 155 detections
# 2019-07-18 18:14:21,721	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.40s
# 2019-07-18 18:14:21,722	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.60s until next run
# 2019-07-18 18:14:41,341	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:14:41,495	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:09:14.808300Z and 2019-07-18T06:13:49.048300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:14:41,496	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:04:14.808300Z and 2019-07-18T06:09:14.788300Z
# 2019-07-18 18:14:41,521	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:14:41,580	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0557s
# 2019-07-18 18:14:41,585	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0039s
# 2019-07-18 18:14:41,624	eqcorrscan.core.match_filter.matched_filter	INFO	Made 78 detections from 11 templates
# 2019-07-18 18:14:41,686	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:14:41,701	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 158 detections
# 2019-07-18 18:14:41,702	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.36s
# 2019-07-18 18:14:41,702	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.64s until next run
# 2019-07-18 18:15:01,361	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:15:01,520	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:09:36.828300Z and 2019-07-18T06:14:02.568300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:15:01,521	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:04:36.828300Z and 2019-07-18T06:09:36.808300Z
# 2019-07-18 18:15:01,550	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:15:01,626	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0731s
# 2019-07-18 18:15:01,631	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0041s
# 2019-07-18 18:15:01,673	eqcorrscan.core.match_filter.matched_filter	INFO	Made 78 detections from 11 templates
# 2019-07-18 18:15:01,736	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:15:01,751	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 161 detections
# 2019-07-18 18:15:01,751	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.39s
# 2019-07-18 18:15:01,752	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.61s until next run
# 2019-07-18 18:15:21,381	rt_eqcorrscan.rt_match_filter	INFO	Starting detection run
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# /home/chambeca/miniconda3/envs/eqcorrscan/lib/python3.7/site-packages/obspy/signal/detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):
# 2019-07-18 18:15:21,548	eqcorrscan.core.match_filter.matched_filter	WARNING	Last bit of data between 2019-07-18T06:10:07.818300Z and 2019-07-18T06:14:36.828300Z will go unused because it is shorter than a chunk of 300.0 s
# 2019-07-18 18:15:21,548	eqcorrscan.core.match_filter.matched_filter	INFO	Computing detections between 2019-07-18T06:05:07.818300Z and 2019-07-18T06:10:07.798300Z
# 2019-07-18 18:15:21,575	eqcorrscan.core.match_filter.matched_filter	INFO	Starting the correlation run for these data
# 2019-07-18 18:15:21,646	eqcorrscan.core.match_filter.matched_filter	INFO	Looping over templates and streams took: 0.0677s
# 2019-07-18 18:15:21,651	eqcorrscan.core.match_filter.matched_filter	INFO	Finding peaks took 0.0048s
# 2019-07-18 18:15:21,691	eqcorrscan.core.match_filter.matched_filter	INFO	Made 76 detections from 11 templates
# 2019-07-18 18:15:21,759	rt_eqcorrscan.rt_match_filter	INFO	Removing duplicate detections
# 2019-07-18 18:15:21,775	rt_eqcorrscan.rt_match_filter	INFO	Party now contains 173 detections
# 2019-07-18 18:15:21,776	rt_eqcorrscan.rt_match_filter	INFO	Detection took 0.40s
# 2019-07-18 18:15:21,776	rt_eqcorrscan.rt_match_filter	INFO	Waiting 19.60s until next run
# 2019-07-18 18:15:41,398	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	INFO	network socket closed
# 2019-07-18 18:15:57,734	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	ERROR	socket read error: [Errno 9] Bad file descriptor, reconnecting in 30ss
# 2019-07-18 18:15:58,236	 obspy.clients.seedlink [rtserve.iris.washington.edu:18000]	WARNING	terminating collect loop
# 2019-07-18 18:15:58,237	rt_eqcorrscan.streaming.streaming	INFO	Termination of Seed-link client at rtserve.iris.washington.edu, status: Stopped, buffer capacity: 600.0s
# 	Current Buffer:
# 6 Trace(s) in Stream:
# LB.TPH.01.HHZ | 2019-07-18T06:05:07.818300Z - 2019-07-18T06:15:07.818300Z | 100.0 Hz, 60001 samples
# LB.TPH.02.HHZ | 2019-07-18T06:05:09.028300Z - 2019-07-18T06:15:09.028300Z | 100.0 Hz, 60001 samples
# PB.B076..EHZ  | 2019-07-18T06:04:56.358400Z - 2019-07-18T06:14:56.358400Z | 100.0 Hz, 60001 samples
# PB.B079..EHZ  | 2019-07-18T06:04:57.908400Z - 2019-07-18T06:14:57.908400Z | 100.0 Hz, 60001 samples
# PB.B900..EHZ  | 2019-07-18T06:04:55.978400Z - 2019-07-18T06:14:55.978400Z | 100.0 Hz, 60001 samples
# PB.B901..EHZ  | 2019-07-18T06:05:13.608400Z - 2019-07-18T06:15:13.608400Z | 100.0 Hz, 60001 samples
# Party of 4 Families.

# %% [markdown]
# This will store detections in a `detections` directory.
